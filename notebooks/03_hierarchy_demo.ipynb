# %% [markdown]
# # Hierarchy Demo
#
# ## Demonstrating multi-level GRA architecture

# %%
from gra_swarm.hierarchy import MultiLevelSystem

system = MultiLevelSystem(n_levels=3)
system.initialize_states(state_dim=10)
