# %% [markdown]
# # Foam Visualization
#
# ## Visualizing swarm foam convergence

# %%
from gra_swarm.utils.visualization import FoamVisualizer

viz = FoamVisualizer()
viz.plot_foam_convergence(foam_history)
